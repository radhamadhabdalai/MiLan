# %%
######################################################################################
Copyright (c) 2023, 2024 , Prof. Radhamadhab Dalai, ITER , Siksha O Aanusandhan University, 
Odisha, India
Author's email address :  radhamadhabdalai@soa.ac.in
###################################################################################

import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Sample data: weight (grams) and color score (0-10)
data = {
    'Weight': [130, 150, 170, 180, 120, 140, 160],  # grams
    'Color_Score': [8, 7, 9, 6, 5, 7, 8],  # 0-10 scale
    'Fruit': ['Apple', 'Apple', 'Apple', 'Orange', 'Orange', 'Orange', 'Orange']
}

df = pd.DataFrame(data)


# Convert 'Fruit' into numerical values: Apple=1, Orange=0
df['Fruit'] = df['Fruit'].map({'Apple': 1, 'Orange': 0})


# Defining X and Y
X = df[['Weight', 'Color_Score']]
y = df['Fruit']

# Linear Regression Model
model = LinearRegression()
model.fit(X, y)


# Coefficients
print("Slope:", model.coef_)
print("Intercept:", model.intercept_)

# Predicting
sample_data = [[160, 6]]  # Sample: Weight = 160g, Color Score = 6
prediction = model.predict(sample_data)
print("Predicted Fruit:", 'Apple' if prediction >= 0.5 else 'Orange')


# Scatter plot
plt.scatter(df['Weight'], df['Color_Score'], c=df['Fruit'], cmap='viridis')
plt.xlabel('Weight')
plt.ylabel('Color Score')
plt.title('Fruit Classification')
plt.show()
# Out:
# Slope: [-0.00575693  0.26865672]
# Intercept: -0.6268656716417913
# Predicted Fruit: Orange
# /home/iter/anaconda3/envs/cnn38/lib/python3.8/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
