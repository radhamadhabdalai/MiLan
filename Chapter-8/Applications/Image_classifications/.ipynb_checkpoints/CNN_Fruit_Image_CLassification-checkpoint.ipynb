# %%
#############################################################################################################
    #Copyright (c) 2023, 2024 , Prof. Radhamadhab Dalai, ITER , Siksha O Aanusandhan University
    #Odisha, India,
    #Author's email address :  radhamadhabdalai@soa.ac.in
 ############################################################################################################

## datset

import os
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.utils import img_to_array


from PIL import Image
from glob import glob
from google.colab import drive

# #Mounting the drivefrom google.colab import drive
# # issue with Keyerror - CLOUDSDK_CONFIG -- configure accordingly
# drive.mount('/content/gdrive')
# #Setting kaggle configuration directory
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# %cd /content/gdrive/My Drive/Kaggle
# #Downloading and unzip dataset
# !kaggle datasets download -d moltean/fruits
# !unzip \*.zip && rm *.zip


###

#Printing all file names under the input directory
for dirname, _, filenames in os.walk('./fruits-360'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        flag = True

## image output only

#Setting Training & Test dir paths
train_path = './fruits-360/Training/'
test_path = './fruits-360/Test/'
#Displaying the image
img = load_img(train_path + "Apple Braeburn/0_100.jpg", target_size=(100,100))
plt.imshow(img)
plt.axis("off")
plt.show()
#Printing the shape of the image array 
x = img_to_array(img)
print(x.shape)

#Visualizing more Images
# images = ['Orange', 'Banana', 'Cauliflower', 'Cactus fruit', 'Eggplant', 'Avocado', 'Watermelon','Lychee', 'Walnut']

images = ['Apple Crimson Snow', 'Apple Golden 1', 'Banana']
fig = plt.figure(figsize =(10,5))
for i in range(len(images)):
    ax = fig.add_subplot(3,3,i+1,xticks=[],yticks=[])
    plt.title(images[i])
    plt.axis("off")
    ax.imshow(load_img(train_path + images[i] +"/0_100.jpg", target_size=(100,100)))


#Storing occurences of fruits in a list
fruits = []
fruits_image = []
for i in os.listdir(train_path):
    for image_filename in os.listdir(train_path + i):
        fruits.append(i) 
        fruits_image.append(i + '/' + image_filename)
#Finding top 10 frequent Fruits
newData = Counter(fruits)
frequent_fruits = newData.most_common(10)
print("Top 10 frequent Fruits:")
frequent_fruits

#Finding number of classes
className = glob(train_path + '/*')
number_of_class = len(className)
print(number_of_class)
# Out:
# /home/iter/anaconda3/envs/cnn38/lib/python3.8/site-packages/google/colab/data_table.py:30: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   from IPython.utils import traitlets as _traitlets
# (100, 100, 3)
# Top 10 frequent Fruits:
# 34

# %%
import os
# from collections import C
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from PIL import Image
from glob import glob
# from google.colab import driveounter
# from google.colab import drive
#Creating the model
model = Sequential()
model.add(Conv2D(32,(3,3),input_shape = x.shape))
model.add(Activation("relu"))
model.add(MaxPooling2D())
model.add(Conv2D(32,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D())
model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(Dropout(0.5))
model.add(Dense(number_of_class)) 
model.add(Activation("softmax"))

#Compiling the model
model.compile(loss = "categorical_crossentropy",
optimizer = "rmsprop",
metrics = ["accuracy"])

#Getting model's summary
model.summary()

#Specifing epochs & batch size
epochs = 100
batch_size = 64


#Creating an object of ImageDataGenerator.
train_datagen = ImageDataGenerator(rescale= 1./255,
shear_range = 0.3,
horizontal_flip=True,
zoom_range = 0.3)
test_datagen = ImageDataGenerator(rescale= 1./255)
#Generating batches of Augmented data.
train_generator = train_datagen.flow_from_directory(
directory = train_path,
target_size= x.shape[:2],
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical")
test_generator = test_datagen.flow_from_directory(
directory = test_path,
target_size= x.shape[:2],
batch_size = batch_size,
color_mode= "rgb",
class_mode= "categorical")

#Fitting the model
hist = model.fit_generator(
generator = train_generator,
steps_per_epoch = 1600 // batch_size,
epochs=epochs,
validation_data = test_generator,
validation_steps = 800 // batch_size)

#Plotting train & validation loss
plt.figure()
plt.plot(hist.history["loss"],label = "Train Loss", color = "black")
plt.plot(hist.history["val_loss"],label = "Validation Loss", color = "mediumvioletred", linestyle="dashed",markeredgecolor = "purple", markeredgewidth = 2)
plt.title("Model Loss", color = "darkred", size = 13)
plt.legend()
plt.show()

#Plotting train & validation accuracy
plt.figure()
plt.plot(hist.history["accuracy"],label = "Train Accuracy", color = "black")
plt.plot(hist.history["val_accuracy"],label = "Validation Accuracy", color = "mediumvioletred", linestyle="dashed",markeredgecolor = "purple", markeredgewidth = 2)
plt.title("Model Accuracy", color = "darkred", size = 13)
plt.legend()
plt.show()

#Predicting the class
prediction = (np.argmax(model.predict(image), axis=-1))
print(prediction)

#Printing class dictionary
print(test_generator.class_indices)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  activation (Activation)     (None, 98, 98, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 32)        9248
#
#  activation_1 (Activation)   (None, 47, 47, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 64)        18496
#
#  activation_2 (Activation)   (None, 21, 21, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 1024)              6554624
#
#  activation_3 (Activation)   (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 34)                34850
#
#  activation_4 (Activation)   (None, 34)                0
#
# =================================================================
# Total params: 6618114 (25.25 MB)
# Trainable params: 6618114 (25.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Found 17206 images belonging to 34 classes.
# Found 5756 images belonging to 34 classes.
# /tmp/ipykernel_15883/492245866.py:66: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(
# Epoch 1/100
# 25/25 [==============================] - 8s 286ms/step - loss: 3.2459 - accuracy: 0.0994 - val_loss: 2.3924 - val_accuracy: 0.2982
# Epoch 2/100
# 25/25 [==============================] - 7s 297ms/step - loss: 2.2588 - accuracy: 0.2956 - val_loss: 1.8219 - val_accuracy: 0.3958
# Epoch 3/100
# 25/25 [==============================] - 8s 317ms/step - loss: 1.6053 - accuracy: 0.4812 - val_loss: 1.3890 - val_accuracy: 0.4896
# Epoch 4/100
# 25/25 [==============================] - 8s 321ms/step - loss: 1.2805 - accuracy: 0.5869 - val_loss: 0.7122 - val_accuracy: 0.8021
# Epoch 5/100
# 25/25 [==============================] - 8s 322ms/step - loss: 0.9714 - accuracy: 0.6769 - val_loss: 0.7154 - val_accuracy: 0.7604
# Epoch 6/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.7039 - accuracy: 0.7663 - val_loss: 0.4719 - val_accuracy: 0.8346
# Epoch 7/100
# 25/25 [==============================] - 8s 336ms/step - loss: 0.6338 - accuracy: 0.7850 - val_loss: 1.0191 - val_accuracy: 0.7122
# Epoch 8/100
# 25/25 [==============================] - 8s 331ms/step - loss: 0.6151 - accuracy: 0.7781 - val_loss: 0.4188 - val_accuracy: 0.8333
# Epoch 9/100
# 25/25 [==============================] - 8s 320ms/step - loss: 0.5138 - accuracy: 0.8231 - val_loss: 0.4002 - val_accuracy: 0.8906
# Epoch 10/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.4198 - accuracy: 0.8612 - val_loss: 0.3241 - val_accuracy: 0.8854
# Epoch 11/100
# 25/25 [==============================] - 8s 312ms/step - loss: 0.4393 - accuracy: 0.8519 - val_loss: 0.3055 - val_accuracy: 0.8841
# Epoch 12/100
# 25/25 [==============================] - 8s 310ms/step - loss: 0.3640 - accuracy: 0.8781 - val_loss: 0.1923 - val_accuracy: 0.9427
# Epoch 13/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.3473 - accuracy: 0.8806 - val_loss: 0.4310 - val_accuracy: 0.8151
# Epoch 14/100
# 25/25 [==============================] - 8s 308ms/step - loss: 0.2895 - accuracy: 0.9044 - val_loss: 0.2881 - val_accuracy: 0.8802
# Epoch 15/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.3663 - accuracy: 0.8794 - val_loss: 0.2526 - val_accuracy: 0.8997
# Epoch 16/100
# 25/25 [==============================] - 8s 312ms/step - loss: 0.2454 - accuracy: 0.9231 - val_loss: 0.1544 - val_accuracy: 0.9583
# Epoch 17/100
# 25/25 [==============================] - 8s 312ms/step - loss: 0.2639 - accuracy: 0.9100 - val_loss: 0.1125 - val_accuracy: 0.9661
# Epoch 18/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.2217 - accuracy: 0.9225 - val_loss: 0.1283 - val_accuracy: 0.9518
# Epoch 19/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.3038 - accuracy: 0.9056 - val_loss: 0.1797 - val_accuracy: 0.9375
# Epoch 20/100
# 25/25 [==============================] - 8s 321ms/step - loss: 0.1970 - accuracy: 0.9331 - val_loss: 0.2757 - val_accuracy: 0.8984
# Epoch 21/100
# 25/25 [==============================] - 8s 314ms/step - loss: 0.2159 - accuracy: 0.9262 - val_loss: 1.0267 - val_accuracy: 0.7773
# Epoch 22/100
# 25/25 [==============================] - 8s 306ms/step - loss: 0.2322 - accuracy: 0.9200 - val_loss: 0.2142 - val_accuracy: 0.9258
# Epoch 23/100
# 25/25 [==============================] - 8s 306ms/step - loss: 0.2131 - accuracy: 0.9294 - val_loss: 0.1075 - val_accuracy: 0.9596
# Epoch 24/100
# 25/25 [==============================] - 8s 308ms/step - loss: 0.1101 - accuracy: 0.9619 - val_loss: 0.2149 - val_accuracy: 0.9271
# Epoch 25/100
# 25/25 [==============================] - 8s 307ms/step - loss: 0.2857 - accuracy: 0.9212 - val_loss: 0.1371 - val_accuracy: 0.9427
# Epoch 26/100
# 25/25 [==============================] - 8s 314ms/step - loss: 0.1211 - accuracy: 0.9613 - val_loss: 0.1232 - val_accuracy: 0.9388
# Epoch 27/100
# 25/25 [==============================] - 8s 307ms/step - loss: 0.1870 - accuracy: 0.9362 - val_loss: 0.1221 - val_accuracy: 0.9479
# Epoch 28/100
# 25/25 [==============================] - 8s 316ms/step - loss: 0.1691 - accuracy: 0.9438 - val_loss: 0.1224 - val_accuracy: 0.9518
# Epoch 29/100
# 25/25 [==============================] - 8s 328ms/step - loss: 0.1486 - accuracy: 0.9531 - val_loss: 0.1082 - val_accuracy: 0.9570
# Epoch 30/100
# 25/25 [==============================] - 8s 313ms/step - loss: 0.1307 - accuracy: 0.9556 - val_loss: 0.1300 - val_accuracy: 0.9323
# Epoch 31/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.1256 - accuracy: 0.9581 - val_loss: 0.1156 - val_accuracy: 0.9518
# Epoch 32/100
# 25/25 [==============================] - 8s 324ms/step - loss: 0.0954 - accuracy: 0.9619 - val_loss: 0.4129 - val_accuracy: 0.8646
# Epoch 33/100
# 25/25 [==============================] - 8s 317ms/step - loss: 0.1422 - accuracy: 0.9525 - val_loss: 0.1146 - val_accuracy: 0.9622
# Epoch 34/100
# 25/25 [==============================] - 8s 333ms/step - loss: 0.0948 - accuracy: 0.9669 - val_loss: 0.1559 - val_accuracy: 0.9544
# Epoch 35/100
# 25/25 [==============================] - 8s 326ms/step - loss: 0.1112 - accuracy: 0.9654 - val_loss: 0.1072 - val_accuracy: 0.9596
# Epoch 36/100
# 25/25 [==============================] - 8s 334ms/step - loss: 0.0993 - accuracy: 0.9631 - val_loss: 0.1402 - val_accuracy: 0.9388
# Epoch 37/100
# 25/25 [==============================] - 8s 329ms/step - loss: 0.1537 - accuracy: 0.9531 - val_loss: 0.1088 - val_accuracy: 0.9544
# Epoch 38/100
# 25/25 [==============================] - 8s 309ms/step - loss: 0.0974 - accuracy: 0.9725 - val_loss: 0.1552 - val_accuracy: 0.9453
# Epoch 39/100
# 12/25 [=============>................] - ETA: 3s - loss: 0.0592 - accuracy: 0.9789
